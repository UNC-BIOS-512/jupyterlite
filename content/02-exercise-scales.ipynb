# %% [markdown]
# Import `ggplot2` and `ISLR2`

# %%
library('ggplot2')
library('ISLR2')

# %% [markdown]
# # Hitters salary

# %% [markdown]
# The `Hitters` dataset has one row per baseball player, including yearly `Salary` (in thousands of dollars). Some players are missing a salary value.
#
# Preview the first six rows of `Hitters` using `head`.

# %% [markdown]
# Plot a histogram of `Salary`: `aes(x = Salary)` with `geom_histogram`.
#
# What shape is the distribution?

# %% [markdown]
# Most salaries are low, with a few very high ones stretching the x axis. Add `scale_x_log10()` to your chart.
#
# How does the shape change?

# %% [markdown]
# # Bonus: two log scales

# %% [markdown]
# Make a scatter plot (`geom_point`) of `Salary` versus career home runs (`CHmRun`), with `scale_x_log10()` on the salary axis.
#
# `CHmRun` spans a wide range too. Try adding `scale_y_log10()` as well. Does it help?
