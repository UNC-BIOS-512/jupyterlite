# %% [markdown]
# # ECDF exercise

# %% [markdown]
# Load `dplyr` and `ggplot2`.

# %%
# Load packages here

# %% [markdown]
# We are using the [GSS](https://gss.norc.org/) data. Here is a quote from the GSS website about the dataset:
# > The General Social Survey (GSS) is a nationally representative survey of adults in the United States conducted since 1972. The GSS collects data on contemporary American society in order to monitor and explain trends in opinions, attitudes and behaviors. The GSS has adapted questions from earlier surveys, thereby allowing researchers to conduct comparisons for up to 80 years.

# %%
# This cell will load the data for you.

gss = readr::read_csv('https://raw.githubusercontent.com/UNC-BIOS-512/jupyterlite/main/data/gss_subset.csv', show_col_types = FALSE)

gss |> glimpse()

# %% [markdown]
# **Compare the `realinc` (real income) of people before and after 1995 with a histogram.**
#
# To do this, we need to:
# 1. Add a column called `pre_1995` that indicates whether the `year` variable is pre 1995 or not.
# 2. Create the histogram, encode `pre_1995` with `fill` and make the histograms overlap with `position="identity"`. Don't forget to set alpha so we can see both histograms fully!
# 3. Use `scale_x_continuous(labels = scales::label_dollar(scale = 1/1000, suffix = "K"))` to scale the x-axis text to money format.

# %%
# Histogram goes here

# %% [markdown]
# **Now compare `realinc` of people before/after 1995 with an ECDF chart.**
#
# *Make the `ecdf_value` column using `dplyr` operations!*

# %%
# ECDF goes here
