# %% [markdown]
# Import `ggplot2`

# %%
library('ggplot2')

# %% [markdown]
# # Histograms and KDE

# %% [markdown]
# Preview the `diamonds` data set:

# %% [markdown]
# Here is the diamonds set filtered to diamonds with clarity values of `I1` and `IF`.

# %%
df = diamonds |> dplyr::filter(clarity %in% c('I1', 'IF'))

df |> head()

# %% [markdown]
# Using 🔗[`facet_wrap`](https://ggplot2.tidyverse.org/reference/facet_wrap.html), plot a histogram of `price` where each plot panel represents one `clarity` value (i.e. `I1` or `IF`).

# %% [markdown]
# Do the same with the KDE geom (`geom_density`).

# %% [markdown]
# With the KDE geom, plot the two clarity groups on top of each other (*Hint: apply an aesthetic
# mapping of `fill` to `clarity`*).
#
# Hint: adjust `alpha` so you can see and compare the distributions.

# %% [markdown]
# # Rugs

# %% [markdown]
# Add a rug to your `diamonds` histogram: `geom_rug`.
