# %%
library('ggplot2')
library('dplyr')

# %% [markdown]
# Let's work with a dataset of [Boston marathon champions](https://www.baa.org/races/boston-marathon/results/champions/). Each row in the table below is a Boston Marathon winner in the given year.

# %%
marathon = readr::read_csv('https://raw.githubusercontent.com/UNC-BIOS-512/jupyterlite/main/data/marathon.csv', show_col_types = FALSE) |>
    mutate(time = lubridate::as.duration(time))

marathon |> glimpse()

# %% [markdown]
# Make a plot of winning race time by year. Group or facet by the `MF` category.

# %%
# Put your plot here

# %% [markdown]
# Can you use `slice_min` to find fastest winning race time for women runners from Kenya and the US?
#
# *Hint: `slice_min(time, n = 1)` gives you the row for the fastest time.*

# %%
# Code goes here
