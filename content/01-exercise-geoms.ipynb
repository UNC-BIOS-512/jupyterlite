# %% [markdown]
# Import `ggplot2`

# %%
library('ggplot2')

options(repr.plot.width=4, repr.plot.height=3, repr.plot.res = 300)

# %% [markdown]
# # Bars

# %% [markdown]
# Let's use the "diamonds" data set. Preview the first six rows of the diamonds dataset using the `head` function.
# (*Hint: try* `?head` *to get the help page for the* `head` *function*)

# %% [markdown]
# Make a bar chart of the "cut" column: `aes(x = cut)` with `geom_bar`.
#
# About how many rows are there for the cut category "Ideal"?

# %% [markdown]
# # Lines

# %% [markdown]
# The cell below creates a table for us of monthly international airline passenger counts from 1949–1960.

# %%
airpassengers <- data.frame(
  date  = seq(as.Date("1949-01-01"), by = "month", length.out = length(AirPassengers)),
  n_passengers = as.numeric(AirPassengers)
)

airpassengers |> head() |> display()

# %% [markdown]
# Make a 📈 line chart of `n_passengers` over time.

# %% [markdown]
# # Smooth

# %% [markdown]
# Plot a scatter plot (`geom_point`) of carat versus price with the diamonds dataset.

# %% [markdown]
# There is a lot of overplotting in this figure. Make the same plot but use the `alpha` value to reduce
# the opacity of the points.
# (*Hint: alpha values can be set from 0 (transparent) to 1 (opaque)*)

# %% [markdown]
# Facetting can also help with overplotting. Facet the chart by `cut`: add `facet_wrap(~cut)` to your chart...

# %%
# options(repr.plot.width=7, repr.plot.height=6)

# %% [markdown]
# Add a `geom_smooth` to your facetted plot to emphasize the trend in the data.
