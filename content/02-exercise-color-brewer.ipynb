# %%
library('ggplot2')
library('RColorBrewer')

# %% [markdown]
# Let's work with this correlation matrix

# %%
cors <- cor(mtcars)
cor_df <- as.data.frame(as.table(cors))
names(cor_df) <- c("var1", "var2", "correlation")

cor_df |> head() |> display()

# %% [markdown]
# Make a chart with `geom_tile`. Use `var1` and `var2` for the *x* and *y* encodings, respectively. `fill` will encode `correlation`.

# %% [markdown]
# Now use ad `scale_fill_distiller(palette = "PuOr", limits = c(-1, 1))`.
#
# Remove the axis labels and switch to `theme_minimal`.

# %% [markdown]
# You can pick a different palette if you want:
#
# ![image.png](attachment:88b0fa75-22a0-42bf-93af-924f1ed4668a.png)
