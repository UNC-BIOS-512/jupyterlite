# %%
library('dplyr')
library('ggplot2')
library('tidyr')
library('stringr')

# %% [markdown]
# Take a look at the `billboard` data set (i.e. use `glimpse`).

# %% [markdown]
# Let's say we want to rank songs based on how many weeks they were in the Top 10.
#
# Can you use a markdown cell to outline the steps? Assume the data looks like this, with one row per song per week:
#
# | artist | track | week | rank |
# |---|---|---|---|
# | 2 Pac | Baby Don't Cry | wk1 | 87 |
# | 2 Pac | Baby Don't Cry | wk2 | 82 |
# | 2 Pac | Baby Don't Cry | wk3 | 72 |
# | Creed | Higher | wk1 | 81 |
# | Creed | Higher | wk2 | 77 |
# | Creed | Higher | wk3 | 73 |
# | ... | ... | ... | ... |

# %% [markdown]
# Run this pivot operation.

# %%
billboard |> 
    pivot_longer(
        cols = starts_with('wk'),
        names_to = 'week',
        values_to = 'rank'
    ) |>
    glimpse()

# %% [markdown]
# Can you apply your steps from above to the "pivoted" data to find the tracks that were ranked in the Top 10 of the Billboard Hot 100 for the most weeks over the time period of the data set?
