# %% [markdown]
# ## Forcats practice

# %% [markdown]
# Load `dplyr`, `ggplot2`, and `forcats`.

# %% [markdown]
# For this exercise we will expore 311 requests in NYC from the [NYC Open Data](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2020-to-Present/erm2-nwe9/about_data) project.

# %%
url = "https://raw.githubusercontent.com/UNC-BIOS-512/jupyterlite/refs/heads/main/data/nyc311.csv"
nyc311 = read.csv(url) 
nyc311 |> glimpse()

# %% [markdown]
# Make a chart showing the frequencies of the `agency` column. This represents the responding city agency that handled the complaint.

# %%
# Code goes here

# %% [markdown]
# Now explore frequencies of `complaint_type`. This variable has many more distinct values so you should lump the low frequency values into an 'Other' category before plotting.

# %%
# Chart code goes here
